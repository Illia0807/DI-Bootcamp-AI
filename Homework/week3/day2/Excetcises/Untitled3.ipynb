# %% [markdown]
# Exercises
# ex1
# A company’s financial reports stored in an Excel file-structured
# Photographs uploaded to a social media platform.-unstructured
# A collection of news articles on a website.-unstructured(semistructure also)
# Inventory data in a relational database.-structured
# Recorded interviews from a market research study.-unstructured

# %% [markdown]
# Exercise 2:
# For each of the following unstructured data sources, propose a method to convert it into structured data. Explain your reasoning.
#
# "From the presented list of unstructured data, it can be seen that they have different content origins and storage methods. Therefore, each task requires a tool that is designed to work in a specific domain."
#
# "And therefore, there is a previously developed methodology for applying this tool, which is why..."
#
# A series of blog posts about travel experiences.-Natural Language Processing
# Audio recordings of customer service calls.-Speech-to-Text
# Handwritten notes from a brainstorming session.-Optical Character Recognition
# A video tutorial on cooking.- Speech-to-Tex

# %% [markdown]
# ex3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f7163904-da48-4a14-933d-d31ea2370555" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f7163904-da48-4a14-933d-d31ea2370555">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd


df = pd.read_csv("train.csv")
print(df.head(2))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ex4

# %%
import pandas as pd
uploaded = files.upload()
df1 = pd.read_csv("Iris_dataset.csv")
print(df1.head())
# Out:
#      <input type="file" id="files-0c91e314-c9b9-4eb0-91ea-be990369bf9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c91e314-c9b9-4eb0-91ea-be990369bf9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Ex5

# %%
import pandas as pd
from google.colab import files


data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'Berlin']
}

df2 = pd.DataFrame(data)
print(df2)
df2.to_json("people.json", orient="records", indent=4)
df2.to_excel("people.xlsx", index=False)
files.download("people.json")
files.download("people.xlsx")
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    Berlin

# %% [markdown]
# ex6

# %%
import pandas as pd
from google.colab import files


uploaded = files.upload()
df3=pd.read_json("posts.json")

print(df3.head(5))
# Out:
#      <input type="file" id="files-1d611506-41de-4701-8f64-afb2f5a7cc4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d611506-41de-4701-8f64-afb2f5a7cc4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
