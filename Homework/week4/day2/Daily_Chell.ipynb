# %%
import numpy as np
import pandas as pd

# %%
data = np.random.uniform(-5, 35, size=(10, 12))
print(data)

cities = ['New York', 'Tokyo', 'Paris', 'London', 'Berlin',
          'Sydney', 'Toronto', 'Dubai', 'Moscow', 'São Paulo']

months = ['January', 'February', 'March', 'April', 'May', 'June',
          'July', 'August', 'September', 'October', 'November', 'December']
df = pd.DataFrame(data, index=cities, columns=months)
print(df)
# Out:
# [[ 1.52328402  8.68805987 31.46537913  5.74965775 23.509895   20.96319343
#   15.01592859 30.62576876  9.10552438 14.48721302 19.1836148  33.94351437]
#  [-0.38123741  0.87924714 20.10742854  3.34760055  7.20980529 19.16221495
#   10.36871954  6.1846285  17.26699044 10.49678531  9.04406341 32.18545398]
#  [23.79877996 21.98661179 26.67646484 29.86785136 29.53352311 -1.45373735
#   20.32846704 12.30276684 32.06906849 12.49289407 24.52674211 26.95684889]
#  [15.82871913  5.11337458 26.70997033 25.94798864 -4.35193028  8.60027651
#   17.70837838 34.90036865 31.72396637  5.4482842  30.49035089  2.02806333]
#  [12.76925141 33.22724806 -2.17549042 -4.27217025  7.11307299 15.25838827
#   -2.75182214  3.54370505 19.85984588  5.70142026 11.12280091  9.28395876]
#  [26.48252609  9.63302489  5.85017154  4.46350002 13.19042683 32.2811521
#   15.20394655 -1.79668056 12.69796171  3.85175238 20.33773953 -1.9710068 ]
#  [20.90096512  0.81486474 -4.66026886  5.05995333 22.40467534  3.76762972
# ...

# %%
annual_avg = df.mean(axis=1)
hottest_city = annual_avg.idxmax()
coldest_city = annual_avg.idxmin()
print('hotest city '+hottest_city)
print('coldest cit '+coldest_city)
# Out:
# hotest city Paris
# coldest cit Berlin

# %%
import matplotlib.pyplot as plt
df.T.plot(figsize=(10, 6), title='Monthly Temperature Trends')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
annual_avg.plot(kind='bar', title='Average Annual Temperature by City')
plt.ylabel('Temperature (°C)')
plt.show()
